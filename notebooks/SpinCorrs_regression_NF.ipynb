# %%
import torch
import uproot
import random
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm
import lightning as L

# %%
# basic random seed
def seed_basic(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)


# torch random seed
def seed_torch(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# basic + torch + lightning
def seed_everything(seed=42):
    seed_basic(seed)
    seed_torch(seed)
    L.seed_everything(seed)


seed_everything()
# Out:
# Seed set to 42

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
file_sm = uproot.open("../data/SM.root")
file = uproot.open("../data/DM.root")

df_DM = file['LHE'].arrays(file['LHE'].keys(), library="pd")
df_SM = file_sm['LHE'].arrays(file_sm['LHE'].keys(), library="pd")
df_SM['M_phi'] = np.sqrt(df_SM['E_phi']**2 - (df_SM['p_phi_x']**2 + df_SM['p_phi_y']**2 + df_SM['p_phi_z']**2))
df_DM['M_phi'] = np.sqrt(df_DM['E_phi']**2 - (df_DM['p_phi_x']**2 + df_DM['p_phi_y']**2 + df_DM['p_phi_z']**2))

train_raw_SM, test_raw_SM = train_test_split(df_SM, test_size=0.2)
train_raw_SM, val_raw_SM = train_test_split(train_raw_SM, test_size=0.2)

train_raw_DM, test_raw_DM = train_test_split(df_DM, test_size=0.2)
train_raw_DM, val_raw_DM = train_test_split(train_raw_DM, test_size=0.2)

train_raw = pd.concat([train_raw_SM, train_raw_DM], axis=0) # We use the 1/1 mix of SM and DM datasets for training
val_raw = pd.concat([val_raw_SM, val_raw_DM], axis=0)
test_raw = pd.concat([test_raw_SM, test_raw_DM], axis=0)

# %%
y_vars = ['p_nu_x', 'p_nu_y', 'p_nu_z', 'p_phi_x', 'p_phi_y', 'p_phi_z']
X_vars = ['p_l_x', 'p_l_y', 'p_l_z', 'p_b_x', 'p_b_y', 'p_b_z', 'p_q_x', 'p_q_y',
          'p_q_z', 'MET_x', 'MET_y', 'MET_z', 'Pt_Lep', 'Eta_Lep', 'Pt_J1', 'Eta_J1',
          'Pt_J2', 'Eta_J2', 'Pt_W', 'Eta_W', 'Pt_top', 'Eta_top', 'mW_inv', 'mtop_inv',
          'MtW', 'MtT', 'SP_LepB', 'SP_LepQ', 'SP_QB', 'SP_LepNu', 'SP_BNu', 'SP_QNu',
          'Ht', 'S_hat', 'Dphi_LepQ', 'Dphi_LepNu', 'Dphi_Wb', 'DR_LepQ', 'DR_LepNu', 'DR_Wb']

# %%
scaler_y = StandardScaler()
scaler_y.fit(np.array(train_raw[y_vars]))
scaler_X = StandardScaler()
scaler_X.fit(np.array(train_raw[X_vars]))

X_train_df = pd.DataFrame(scaler_X.transform(np.array(train_raw[X_vars])), columns=X_vars)
X_val_df = pd.DataFrame(scaler_X.transform(np.array(val_raw[X_vars])), columns=X_vars)
X_test_df = pd.DataFrame(scaler_X.transform(np.array(test_raw[X_vars])), columns=X_vars)

y_train_df = pd.DataFrame(scaler_y.transform(np.array(train_raw[y_vars])), columns=y_vars)
y_val_df = pd.DataFrame(scaler_y.transform(np.array(val_raw[y_vars])), columns=y_vars)
y_test_df = pd.DataFrame(scaler_y.transform(np.array(test_raw[y_vars])), columns=y_vars)

# %%
from torch.utils.data import Dataset, DataLoader


class CustomDataset(Dataset):
    def __init__(
        self,
        input_values,
        labels,
        transforms=None,
    ):
        self.input_values = torch.from_numpy(input_values).type(torch.FloatTensor)
        self.labels = torch.from_numpy(labels).type(torch.FloatTensor)
        self.transforms = transforms

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        if self.transforms:
            input_value = self.transforms(self.input_values[idx])
        else:
            input_value = self.input_values[idx]
        label = self.labels[idx]
        return input_value, label

# %%
train_set = CustomDataset(X_train_df.values, y_train_df.values)
val_set = CustomDataset(X_val_df.values, y_val_df.values)
test_set = CustomDataset(X_test_df.values, y_test_df.values)

train_loader = torch.utils.data.DataLoader(
    train_set, batch_size=1024, shuffle=True
)
val_loader = torch.utils.data.DataLoader(
    val_set, batch_size=1024, shuffle=False
)
test_loader = torch.utils.data.DataLoader(
    test_set, batch_size=1024, shuffle=False
)

# %%
import sys
sys.path.append('../src/')
import torch.nn as nn
import torch.nn.functional as F
import sc_models
from torchmetrics.regression import MeanSquaredError, MeanAbsoluteError

# %%
class LModel_NF(L.LightningModule):
    def __init__(
            self, model, lr=1e-4,
        ):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.train_acc = MeanAbsoluteError()
        self.valid_acc = MeanAbsoluteError()
        self.test_acc = MeanAbsoluteError()
        self.lr = lr

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.model.parameters(), lr = self.lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor = 0.5, min_lr = 1e-5)
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "epoch",
                "monitor": "loss/val", 
            },
        }
    def training_step(self, batch, batch_idx):
        x, y = batch
        out = -self.model.log_prob(inputs=y, context=x)
        loss = -self.model.log_prob(inputs=y, context=x).mean()
        self.log("loss/train", loss.detach().item(), prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        out = -self.model.log_prob(inputs=y, context=x)
        loss = -self.model.log_prob(inputs=y, context=x).mean()
        self.log("loss/val", loss.detach().item())

# %%
class LModel(L.LightningModule):

    def __init__(
            self, model, lr=1e-4,
        ):
        super().__init__()
        self.model = model
        self.criterion = nn.L1Loss()
        self.train_acc = MeanAbsoluteError()
        self.valid_acc = MeanAbsoluteError()
        self.test_acc = MeanAbsoluteError()
        self.lr = lr

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.model.parameters(), lr = self.lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor = 0.1, min_lr = 1e-6)
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "epoch",
                "monitor": "loss/val",
            },
        }

    def training_step(self, batch, batch_idx):
        x, y = batch
        out = self.model.forward(x)
        loss = self.criterion(out, y)
        self.train_acc.update((out.detach()), y.detach())
        self.log("loss/train", loss.detach().item(), prog_bar=True)
        return loss
        
    def on_train_epoch_end(self):
        self.log("MAE/train", self.train_acc.compute(), prog_bar=True)
        self.train_acc.reset()
        
    def validation_step(self, batch, batch_idx):
        x, y = batch
        out = self.model.forward(x)
        loss = self.criterion(out, y)
        self.valid_acc.update((out.detach()), y.detach())
        self.log("loss/val", loss.detach().item())
        
    def on_validation_epoch_end(self):
        self.log("MAE/val", self.valid_acc.compute(), prog_bar=True)
        self.valid_acc.reset()

# %%
from lightning.pytorch.callbacks import ModelCheckpoint, EarlyStopping
import warnings
warnings.filterwarnings("ignore")

def create_trainer(name, max_epochs = 10):
    checkpoint_callback = ModelCheckpoint(
    dirpath='../checkpoints/parton',
    save_last=False,
    every_n_epochs=1,
    save_top_k=1,
    monitor="loss/val",
    filename=name,
    mode="min",
    )

    torch.set_float32_matmul_precision('medium')
    trainer = L.Trainer(
        max_epochs=max_epochs,
        callbacks=[checkpoint_callback, EarlyStopping(monitor="loss/val", mode="min", patience = 5)],
        num_sanity_val_steps=1,
        log_every_n_steps=10,
        logger=L.pytorch.loggers.TensorBoardLogger(save_dir=f"../logs/parton/{name}", ),
    )
    return trainer

# %%
mlp_model = sc_models.MLP_net(len(X_vars), len(y_vars), 500, 3, 0.15)
basic_flow = sc_models.Basic_flow(cond_size = len(X_vars), target_size = len(y_vars))
nu_flow = sc_models.Nu_flow(encoder = sc_models.DeepSet(len(X_vars), 20), target_size = len(y_vars), 
                            masking_order = [1, 1, -1, 1, 1, -1],  # masking is done for (x,y) <-> z for neutrino and mediator
                            num_layers = 7, context_size = 20, spline_conf = (100, 3, 0.1))

# %%
pl_model_mlp = LModel(mlp_model)
trainer = create_trainer("mlp", max_epochs = 100)
trainer.fit(
    model=pl_model_mlp,
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type              | Params | Mode
# --------------------------------------------------------
# 0 | model     | MLP_net           | 524 K  | train
# 1 | criterion | L1Loss            | 0      | train
# 2 | train_acc | MeanAbsoluteError | 0      | train
# 3 | valid_acc | MeanAbsoluteError | 0      | train
# 4 | test_acc  | MeanAbsoluteError | 0      | train
# --------------------------------------------------------
# 524 K     Trainable params
# 0         Non-trainable params
# 524 K     Total params
# 2.098     Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 1225/1225 [00:18<00:00, 64.54it/s, v_num=3, loss/train=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/307 [00:00<00:02, 148.51it/s]
# Validation DataLoader 0:   1%|          | 2/307 [00:00<00:02, 119.82it/s]
# Validation DataLoader 0:   1%|          | 3/307 [00:00<00:02, 113.07it/s]
# Validation DataLoader 0:   1%|▏         | 4/307 [00:00<00:02, 108.71it/s]
# Validation DataLoader 0:   2%|▏         | 5/307 [00:00<00:02, 107.91it/s]
# Validation DataLoader 0:   2%|▏         | 6/307 [00:00<00:02, 107.03it/s]
# Validation DataLoader 0:   2%|▏         | 7/307 [00:00<00:02, 106.87it/s]
# Validation DataLoader 0:   3%|▎         | 8/307 [00:00<00:02, 106.79it/s]
# Validation DataLoader 0:   3%|▎         | 9/307 [00:00<00:02, 106.51it/s]
# Validation DataLoader 0:   3%|▎         | 10/307 [00:00<00:02, 105.55it/s]
# Validation DataLoader 0:   4%|▎         | 11/307 [00:00<00:02, 104.80it/s]
# Validation DataLoader 0:   4%|▍         | 12/307 [00:00<00:02, 104.49it/s]
# Validation DataLoader 0:   4%|▍         | 13/307 [00:00<00:02, 104.37it/s]
# Validation DataLoader 0:   5%|▍         | 14/307 [00:00<00:02, 103.80it/s]
# Validation DataLoader 0:   5%|▍         | 15/307 [00:00<00:02, 103.84it/s]
# Validation DataLoader 0:   5%|▌         | 16/307 [00:00<00:02, 103.48it/s]
# Validation DataLoader 0:   6%|▌         | 17/307 [00:00<00:02, 103.40it/s]
# Validation DataLoader 0:   6%|▌         | 18/307 [00:00<00:02, 103.39it/s]
# Validation DataLoader 0:   6%|▌         | 19/307 [00:00<00:02, 103.16it/s]
# Validation DataLoader 0:   7%|▋         | 20/307 [00:00<00:02, 103.26it/s]
# Validation DataLoader 0:   7%|▋         | 21/307 [00:00<00:02, 103.03it/s]
# Validation DataLoader 0:   7%|▋         | 22/307 [00:00<00:02, 103.01it/s]
# Validation DataLoader 0:   7%|▋         | 23/307 [00:00<00:02, 102.94it/s]
# Validation DataLoader 0:   8%|▊         | 24/307 [00:00<00:02, 102.51it/s]
# Validation DataLoader 0:   8%|▊         | 25/307 [00:00<00:02, 102.30it/s]
# Validation DataLoader 0:   8%|▊         | 26/307 [00:00<00:02, 102.12it/s]
# Validation DataLoader 0:   9%|▉         | 27/307 [00:00<00:02, 102.00it/s]
# Validation DataLoader 0:   9%|▉         | 28/307 [00:00<00:02, 101.98it/s]
# Validation DataLoader 0:   9%|▉         | 29/307 [00:00<00:02, 101.82it/s]
# Validation DataLoader 0:  10%|▉         | 30/307 [00:00<00:02, 101.80it/s]
# Validation DataLoader 0:  10%|█         | 31/307 [00:00<00:02, 101.50it/s]
# Validation DataLoader 0:  10%|█         | 32/307 [00:00<00:02, 101.24it/s]
# Validation DataLoader 0:  11%|█         | 33/307 [00:00<00:02, 100.99it/s]
# Validation DataLoader 0:  11%|█         | 34/307 [00:00<00:02, 99.64it/s]
# Validation DataLoader 0:  11%|█▏        | 35/307 [00:00<00:02, 99.58it/s]
# Validation DataLoader 0:  12%|█▏        | 36/307 [00:00<00:02, 99.73it/s]
# Validation DataLoader 0:  12%|█▏        | 37/307 [00:00<00:02, 99.72it/s]
# Validation DataLoader 0:  12%|█▏        | 38/307 [00:00<00:02, 99.82it/s]
# Validation DataLoader 0:  13%|█▎        | 39/307 [00:00<00:02, 99.92it/s]
# Validation DataLoader 0:  13%|█▎        | 40/307 [00:00<00:02, 99.88it/s]
# Validation DataLoader 0:  13%|█▎        | 41/307 [00:00<00:02, 99.70it/s]
# Validation DataLoader 0:  14%|█▎        | 42/307 [00:00<00:02, 99.76it/s]
# Validation DataLoader 0:  14%|█▍        | 43/307 [00:00<00:02, 99.77it/s]
# Validation DataLoader 0:  14%|█▍        | 44/307 [00:00<00:02, 99.76it/s]
# Validation DataLoader 0:  15%|█▍        | 45/307 [00:00<00:02, 99.83it/s]
# Validation DataLoader 0:  15%|█▍        | 46/307 [00:00<00:02, 99.83it/s]
# Validation DataLoader 0:  15%|█▌        | 47/307 [00:00<00:02, 99.81it/s]
# Validation DataLoader 0:  16%|█▌        | 48/307 [00:00<00:02, 99.89it/s]
# Validation DataLoader 0:  16%|█▌        | 49/307 [00:00<00:02, 99.81it/s]
# Validation DataLoader 0:  16%|█▋        | 50/307 [00:00<00:02, 99.80it/s]
# Validation DataLoader 0:  17%|█▋        | 51/307 [00:00<00:02, 99.66it/s]
# Validation DataLoader 0:  17%|█▋        | 52/307 [00:00<00:02, 99.60it/s]
# Validation DataLoader 0:  17%|█▋        | 53/307 [00:00<00:02, 99.52it/s]
# Validation DataLoader 0:  18%|█▊        | 54/307 [00:00<00:02, 99.56it/s]
# Validation DataLoader 0:  29%|██▉       | 90/307 [00:00<00:02, 96.58it/s]
# Validation DataLoader 0:  30%|██▉       | 91/307 [00:00<00:02, 96.45it/s]
# Validation DataLoader 0:  30%|██▉       | 92/307 [00:00<00:02, 96.40it/s]
# Validation DataLoader 0:  30%|███       | 93/307 [00:00<00:02, 96.36it/s]
# Validation DataLoader 0:  31%|███       | 94/307 [00:00<00:02, 96.42it/s]
# Validation DataLoader 0:  31%|███       | 95/307 [00:00<00:02, 96.53it/s]
# Validation DataLoader 0:  31%|███▏      | 96/307 [00:00<00:02, 96.62it/s]
# Validation DataLoader 0:  32%|███▏      | 97/307 [00:01<00:02, 96.64it/s]
# Validation DataLoader 0:  32%|███▏      | 98/307 [00:01<00:02, 96.60it/s]
# Validation DataLoader 0:  32%|███▏      | 99/307 [00:01<00:02, 96.65it/s]
# Validation DataLoader 0:  33%|███▎      | 100/307 [00:01<00:02, 96.66it/s]
# Validation DataLoader 0:  33%|███▎      | 101/307 [00:01<00:02, 96.72it/s]
# Validation DataLoader 0:  33%|███▎      | 102/307 [00:01<00:02, 96.76it/s]
# Validation DataLoader 0:  34%|███▎      | 103/307 [00:01<00:02, 96.78it/s]
# Validation DataLoader 0:  34%|███▍      | 104/307 [00:01<00:02, 96.77it/s]
# Validation DataLoader 0:  34%|███▍      | 105/307 [00:01<00:02, 96.74it/s]
# Validation DataLoader 0:  35%|███▍      | 106/307 [00:01<00:02, 96.77it/s]
# Validation DataLoader 0:  35%|███▍      | 107/307 [00:01<00:02, 96.82it/s]
# Validation DataLoader 0:  35%|███▌      | 108/307 [00:01<00:02, 96.87it/s]
# Validation DataLoader 0:  36%|███▌      | 109/307 [00:01<00:02, 96.91it/s]
# Validation DataLoader 0:  36%|███▌      | 110/307 [00:01<00:02, 96.98it/s]
# Validation DataLoader 0:  36%|███▌      | 111/307 [00:01<00:02, 97.00it/s]
# Validation DataLoader 0:  36%|███▋      | 112/307 [00:01<00:02, 96.98it/s]
# Validation DataLoader 0:  37%|███▋      | 113/307 [00:01<00:02, 96.97it/s]
# Validation DataLoader 0:  37%|███▋      | 114/307 [00:01<00:01, 97.00it/s]
# Validation DataLoader 0:  37%|███▋      | 115/307 [00:01<00:01, 96.99it/s]
# Validation DataLoader 0:  38%|███▊      | 116/307 [00:01<00:01, 97.01it/s]
# Validation DataLoader 0:  38%|███▊      | 117/307 [00:01<00:01, 96.96it/s]
# Validation DataLoader 0:  38%|███▊      | 118/307 [00:01<00:01, 96.93it/s]
# Validation DataLoader 0:  39%|███▉      | 119/307 [00:01<00:01, 96.93it/s]
# Validation DataLoader 0:  39%|███▉      | 120/307 [00:01<00:01, 96.92it/s]
# Validation DataLoader 0:  39%|███▉      | 121/307 [00:01<00:01, 96.96it/s]
# Validation DataLoader 0:  40%|███▉      | 122/307 [00:01<00:01, 96.99it/s]
# Validation DataLoader 0:  40%|████      | 123/307 [00:01<00:01, 97.00it/s]
# Validation DataLoader 0:  40%|████      | 124/307 [00:01<00:01, 97.01it/s]
# Validation DataLoader 0:  41%|████      | 125/307 [00:01<00:01, 97.03it/s]
88it/s]
# Validation DataLoader 0:  76%|███████▌  | 233/307 [00:02<00:00, 97.88it/s]
# Validation DataLoader 0:  76%|███████▌  | 234/307 [00:02<00:00, 97.92it/s]
# Validation DataLoader 0:  77%|███████▋  | 235/307 [00:02<00:00, 97.93it/s]
# Validation DataLoader 0:  77%|███████▋  | 236/307 [00:02<00:00, 97.95it/s]
# Validation DataLoader 0:  77%|███████▋  | 237/307 [00:02<00:00, 97.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 238/307 [00:02<00:00, 97.93it/s]
# Validation DataLoader 0:  78%|███████▊  | 239/307 [00:02<00:00, 97.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 240/307 [00:02<00:00, 97.97it/s]
# Validation DataLoader 0:  79%|███████▊  | 241/307 [00:02<00:00, 97.98it/s]
# Validation DataLoader 0:  79%|███████▉  | 242/307 [00:02<00:00, 97.99it/s]
# Validation DataLoader 0:  79%|███████▉  | 243/307 [00:02<00:00, 98.00it/s]
# Validation DataLoader 0:  79%|███████▉  | 244/307 [00:02<00:00, 98.00it/s]
# Validation DataLoader 0:  80%|███████▉  | 245/307 [00:02<00:00, 98.01it/s]
# Validation DataLoader 0:  80%|████████  | 246/307 [00:02<00:00, 98.03it/s]
# Validation DataLoader 0:  80%|████████  | 247/307 [00:02<00:00, 98.04it/s]
# Validation DataLoader 0:  81%|████████  | 248/307 [00:02<00:00, 98.05it/s]
# Validation DataLoader 0:  81%|████████  | 249/307 [00:02<00:00, 98.06it/s]
# Validation DataLoader 0:  81%|████████▏ | 250/307 [00:02<00:00, 98.05it/s]
# Validation DataLoader 0:  82%|████████▏ | 251/307 [00:02<00:00, 98.04it/s]
# Validation DataLoader 0:  82%|████████▏ | 252/307 [00:02<00:00, 98.03it/s]
# Validation DataLoader 0:  82%|████████▏ | 253/307 [00:02<00:00, 88.78it/s]
# Validation DataLoader 0:  83%|████████▎ | 254/307 [00:02<00:00, 88.83it/s]
# Validation DataLoader 0:  83%|████████▎ | 255/307 [00:02<00:00, 88.88it/s]
# Validation DataLoader 0:  83%|████████▎ | 256/307 [00:02<00:00, 88.91it/s]
# Validation DataLoader 0:  84%|████████▎ | 257/307 [00:02<00:00, 88.96it/s]
# Validation DataLoader 0:  84%|████████▍ | 258/307 [00:02<00:00, 89.00it/s]
# Validation DataLoader 0:  84%|████████▍ | 259/307 [00:02<00:00, 89.03it/s]
# Validation DataLoader 0:  85%|████████▍ | 260/307 [00:02<00:00, 89.07it/s]
# Validation DataLoader 0:  85%|████████▌ | 261/307 [00:02<00:00, 89.11it/s]
# Validation DataLoader 0:  85%|████████▌ | 262/307 [00:02<00:00, 89.14it/s]
# Validation DataLoader 0:  86%|████████▌ | 263/307 [00:02<00:00, 89.18it/s]
# Validation DataLoader 0:  86%|████████▌ | 264/307 [00:02<00:00, 89.21it/s]
# Validation DataLoader 0:  86%|████████▋ | 265/307 [00:02<00:00, 89.25it/s]
# Validation DataLoader 0:  87%|████████▋ | 266/307 [00:02<00:00, 89.30it/s]
# Validation DataLoader 0:  87%|████████▋ | 267/307 [00:02<00:00, 89.33it/s]
# Validation DataLoader 0:  87%|████████▋ | 268/307 [00:02<00:00, 89.38it/s]
# Validation DataLoader 0:  88%|████████▊ | 269/307 [00:03<00:00, 89.42it/s]
# Validation DataLoader 0:  88%|████████▊ | 270/307 [00:03<00:00, 89.45it/s]
# Validation DataLoader 0:  88%|████████▊ | 271/307 [00:03<00:00, 89.48it/s]
# Validation DataLoader 0:  89%|████████▊ | 272/307 [00:03<00:00, 89.54it/s]
# Validation DataLoader 0:  89%|████████▉ | 273/307 [00:03<00:00, 89.56it/s]
# Validation DataLoader 0:  89%|████████▉ | 274/307 [00:03<00:00, 89.58it/s]
# Validation DataLoader 0:  90%|████████▉ | 275/307 [00:03<00:00, 89.63it/s]
# Validation DataLoader 0:  90%|████████▉ | 276/307 [00:03<00:00, 89.67it/s]
# Validation DataLoader 0:  90%|█████████ | 277/307 [00:03<00:00, 89.71it/s]
# Validation DataLoader 0:  91%|█████████ | 278/307 [00:03<00:00, 89.74it/s]
# Validation DataLoader 0:  91%|█████████ | 279/307 [00:03<00:00, 89.75it/s]
# Validation DataLoader 0:  91%|█████████ | 280/307 [00:03<00:00, 89.76it/s]
# Validation DataLoader 0:  92%|█████████▏| 281/307 [00:03<00:00, 89.79it/s]
# Validation DataLoader 0:  92%|█████████▏| 282/307 [00:03<00:00, 89.80it/s]
# Validation DataLoader 0:  92%|█████████▏| 283/307 [00:03<00:00, 89.83it/s]
# Validation DataLoader 0:  93%|█████████▎| 284/307 [00:03<00:00, 89.86it/s]
# Validation DataLoader 0:  93%|█████████▎| 285/307 [00:03<00:00, 89.89it/s]
# Validation DataLoader 0:  93%|█████████▎| 286/307 [00:03<00:00, 89.90it/s]
# Validation DataLoader 0:  93%|█████████▎| 287/307 [00:03<00:00, 89.93it/s]
# Validation DataLoader 0:  94%|█████████▍| 288/307 [00:03<00:00, 89.96it/s]
# Validation DataLoader 0:  94%|█████████▍| 289/307 [00:03<00:00, 89.96it/s]
# Validation DataLoader 0:  94%|█████████▍| 290/307 [00:03<00:00, 90.00it/s]
# Validation DataLoader 0:  95%|█████████▍| 291/307 [00:03<00:00, 90.04it/s]
# Validation DataLoader 0:  95%|█████████▌| 292/307 [00:03<00:00, 90.05it/s]
# Validation DataLoader 0:  95%|█████████▌| 293/307 [00:03<00:00, 90.03it/s]
# Validation DataLoader 0:  96%|█████████▌| 294/307 [00:03<00:00, 90.06it/s]
# Validation DataLoader 0:  96%|█████████▌| 295/307 [00:03<00:00, 90.09it/s]
# Validation DataLoader 0:  96%|█████████▋| 296/307 [00:03<00:00, 90.11it/s]
# Validation DataLoader 0:  97%|█████████▋| 297/307 [00:03<00:00, 90.14it/s]
# Validation DataLoader 0:  97%|█████████▋| 298/307 [00:03<00:00, 90.15it/s]
# Validation DataLoader 0:  97%|█████████▋| 299/307 [00:03<00:00, 90.16it/s]
# Validation DataLoader 0:  98%|█████████▊| 300/307 [00:03<00:00, 90.19it/s]
# Validation DataLoader 0:  98%|█████████▊| 301/307 [00:03<00:00, 90.21it/s]
# Validation DataLoader 0:  98%|█████████▊| 302/307 [00:03<00:00, 90.25it/s]
# Validation DataLoader 0:  99%|█████████▊| 303/307 [00:03<00:00, 90.26it/s]
# Validation DataLoader 0:  99%|█████████▉| 304/307 [00:03<00:00, 90.28it/s]
# Validation DataLoader 0:  99%|█████████▉| 305/307 [00:03<00:00, 90.31it/s]
# Validation DataLoader 0: 100%|█████████▉| 306/307 [00:03<00:00, 90.34it/s]
# Validation DataLoader 0: 100%|██████████| 307/307 [00:03<00:00, 90.50it/s]
# Epoch 1: 100%|██████████| 1225/1225 [00:18<00:00, 65.10it/s, v_num=3, loss/train=0.343, MAE/val=0.351, MAE/train=0.389]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/307 [00:00<00:01, 153.49it/s]
# Validation DataLoader 0:   1%|          | 2/307 [00:00<00:02, 123.02it/s]
# Validation DataLoader 0:   1%|          | 3/307 [00:00<00:02, 115.82it/s]
# Validation DataLoader 0:   1%|▏         | 4/307 [00:00<00:02, 110.58it/s]
# Validation DataLoader 0:   2%|▏         | 5/307 [00:00<00:02, 108.99it/s]
# Validation DataLoader 0:   2%|▏         | 6/307 [00:00<00:02, 108.16it/s]
# Validation DataLoader 0:   2%|▏         | 7/307 [00:00<00:02, 107.42it/s]
# Validation DataLoader 0:   3%|▎         | 8/307 [00:00<00:02, 107.47it/s]
# Validation DataLoader 0:   3%|▎         | 9/307 [00:00<00:02, 106.72it/s]
# Validation DataLoader 0:   3%|▎         | 10/307 [00:00<00:02, 105.21it/s]
# Validation DataLoader 0:   4%|▎         | 11/307 [00:00<00:02, 104.77it/s]
# Validation DataLoader 0:   4%|▍         | 12/307 [00:00<00:02, 104.40it/s]
# Validation DataLoader 0:   4%|▍         | 13/307 [00:00<00:02, 103.63it/s]
# Validation DataLoader 0:   5%|▍         | 14/307 [00:00<00:02, 103.16it/s]
# Validation DataLoader 0:   5%|▍         | 15/307 [00:00<00:02, 102.94it/s]
# Validation DataLoader 0:   5%|▌         | 16/307 [00:00<00:02, 102.72it/s]
# Validation DataLoader 0:   6%|▌         | 17/307 [00:00<00:02, 102.55it/s]
# Validation DataLoader 0:   6%|▌         | 18/307 [00:00<00:02, 102.51it/s]
# Validation DataLoader 0:   6%|▌         | 19/307 [00:00<00:02, 102.35it/s]
# Validation DataLoader 0:   7%|▋         | 20/307 [00:00<00:02, 102.22it/s]
# Validation DataLoader 0:   7%|▋         | 21/307 [00:00<00:02, 101.96it/s]
# Validation DataLoader 0:   7%|▋         | 22/307 [00:00<00:02, 101.82it/s]
# Validation DataLoader 0:   7%|▋         | 23/307 [00:00<00:02, 101.81it/s]
# Validation DataLoader 0:   8%|▊         | 24/307 [00:00<00:02, 101.80it/s]
# Validation DataLoader 0:   8%|▊         | 25/307 [00:00<00:02, 101.74it/s]
# Validation DataLoader 0:   8%|▊         | 26/307 [00:00<00:02, 101.56it/s]
# Validation DataLoader 0:   9%|▉         | 27/307 [00:00<00:02, 101.19it/s]
# Validation DataLoader 0:   9%|▉         | 28/307 [00:00<00:02, 101.00it/s]
# Validation DataLoader 0:   9%|▉         | 29/307 [00:00<00:02, 100.70it/s]
# Validation DataLoader 0:  10%|▉         | 30/307 [00:00<00:02, 100.69it/s]
# Validation DataLoader 0:  10%|█         | 31/307 [00:00<00:02, 100.65it/s]
# Validation DataLoader 0:  10%|█         | 32/307 [00:00<00:02, 100.77it/s]
# Validation DataLoader 0:  11%|█         | 33/307 [00:00<00:02, 100.77it/s]
# Validation DataLoader 0:  11%|█         | 34/307 [00:00<00:02, 100.77it/s]
# Validation DataLoader 0:  11%|█▏        | 35/307 [00:00<00:02, 100.78it/s]
# Validation DataLoader 0:  12%|█▏        | 36/307 [00:00<00:02, 100.79it/s]
# Validation DataLoader 0:  12%|█▏        | 37/307 [00:00<00:02, 100.79it/s]
# Validation DataLoader 0:  12%|█▏        | 38/307 [00:00<00:02, 100.83it/s]
# Validation DataLoader 0:  13%|█▎        | 39/307 [00:00<00:02, 100.76it/s]
# Validation DataLoader 0:  13%|█▎        | 40/307 [00:00<00:02, 100.69it/s]
# Validation DataLoader 0:  13%|█▎        | 41/307 [00:00<00:02, 100.65it/s]
# Validation DataLoader 0:  14%|█▎        | 42/307 [00:00<00:02, 100.60it/s]
# Validation DataLoader 0:  14%|█▍        | 43/307 [00:00<00:02, 100.63it/s]
# Validation DataLoader 0:  14%|█▍        | 44/307 [00:00<00:02, 100.73it/s]
# Validation DataLoader 0:  15%|█▍        | 45/307 [00:00<00:02, 100.61it/s]
# Validation DataLoader 0:  15%|█▍        | 46/307 [00:00<00:02, 100.57it/s]
# Validation DataLoader 0:  15%|█▌        | 47/307 [00:00<00:02, 100.53it/s]
# Validation DataLoader 0:  16%|█▌        | 48/307 [00:00<00:02, 100.55it/s]
# Validation DataLoader 0:  16%|█▌        | 49/307 [00:00<00:02, 100.32it/s]
# Validation DataLoader 0:  16%|█▋        | 50/307 [00:00<00:02, 100.35it/s]
# Validation DataLoader 0:  17%|█▋        | 51/307 [00:00<00:02, 100.37it/s]
# Validation DataLoader 0:  17%|█▋        | 52/307 [00:00<00:02, 100.36it/s]
# Validation DataLoader 0:  17%|█▋        | 53/307 [00:00<00:02, 100.32it/s]
# Validation DataLoader 0:  18%|█▊        | 54/307 [00:00<00:02, 100.31it/s]
# Validation DataLoader 0:  18%|█▊        | 55/307 [00:00<00:02, 100.18it/s]
# Validation DataLoader 0:  18%|█▊        | 56/307 [00:00<00:02, 100.21it/s]
# Validation DataLoader 0:  19%|█▊        | 57/307 [00:00<00:02, 100.25it/s]
# Validation DataLoader 0:  19%|█▉        | 58/307 [00:00<00:02, 100.21it/s]
# Validation DataLoader 0:  19%|█▉        | 59/307 [00:00<00:02, 100.19it/s]
# Validation DataLoader 0:  20%|█▉        | 60/307 [00:00<00:02, 100.21it/s]
# Validation DataLoader 0:  20%|█▉        | 61/307 [00:00<00:02, 100.22it/s]
# Validation DataLoader 0:  20%|██        | 62/307 [00:00<00:02, 100.17it/s]
# Validation DataLoader 0:  21%|██        | 63/307 [00:00<00:02, 100.15it/s]
# Validation DataLoader 0:  21%|██        | 64/307 [00:00<00:02, 100.22it/s]
# Validation DataLoader 0:  21%|██        | 65/307 [00:00<00:02, 100.16it/s]
# Validation DataLoader 0:  21%|██▏       | 66/307 [00:00<00:02, 100.16it/s]
# Validation DataLoader 0:  22%|██▏       | 67/307 [00:00<00:02, 100.16it/s]
# Validation DataLoader 0:  22%|██▏       | 68/307 [00:00<00:02, 100.25it/s]
# Validation DataLoader 0:  22%|██▏       | 69/307 [00:00<00:02, 100.12it/s]
# Validation DataLoader 0:  23%|██▎       | 70/307 [00:00<00:02, 100.07it/s]
# Validation DataLoader 0:  23%|██▎       | 71/307 [00:00<00:02, 100.06it/s]
# Validation DataLoader 0:  23%|██▎       | 72/307 [00:00<00:02, 100.11it/s]
# Validation DataLoader 0:  24%|██▍       | 73/307 [00:00<00:02, 100.12it/s]
# Validation DataLoader 0:  24%|██▍       | 74/307 [00:00<00:02, 100.15it/s]
# Validation DataLoader 0:  24%|██▍       | 75/307 [00:00<00:02, 100.16it/s]
# Validation DataLoader 0:  25%|██▍       | 76/307 [00:00<00:02, 100.19it/s]
# Validation DataLoader 0:  25%|██▌       | 77/307 [00:00<00:02, 100.20it/s]
# Validation DataLoader 0:  25%|██▌       | 78/307 [00:00<00:02, 100.24it/s]
# Validation DataLoader 0:  26%|██▌       | 79/307 [00:00<00:02, 100.26it/s]
# Validation DataLoader 0:  26%|██▌       | 80/307 [00:00<00:02, 100.25it/s]
# Validation DataLoader 0:  26%|██▋       | 81/307 [00:00<00:02, 100.23it/s]
# Validation DataLoader 0:  27%|██▋       | 82/307 [00:00<00:02, 100.26it/s]
# Validation DataLoader 0:  27%|██▋       | 83/307 [00:00<00:02, 100.33it/s]
# Validation DataLoader 0:  27%|██▋       | 84/307 [00:00<00:02, 100.33it/s]
# Validation DataLoader 0:  28%|██▊       | 85/307 [00:00<00:02, 100.33it/s]
# Validation DataLoader 0:  28%|██▊       | 86/307 [00:00<00:02, 100.29it/s]
# Validation DataLoader 0:  28%|██▊       | 87/307 [00:00<00:02, 100.28it/s]
# Validation DataLoader 0:  29%|██▊       | 88/307 [00:00<00:02, 100.31it/s]
# Validation DataLoader 0:  29%|██▉       | 89/307 [00:00<00:02, 100.34it/s]
# Validation DataLoader 0:  29%|██▉       | 90/307 [00:00<00:02, 100.31it/s]
# Validation DataLoader 0:  30%|██▉       | 91/307 [00:00<00:02, 100.28it/s]
# Validation DataLoader 0:  30%|██▉       | 92/307 [00:00<00:02, 100.31it/s]
# Validation DataLoader 0:  30%|███       | 93/307 [00:00<00:02, 100.30it/s]
# Validation DataLoader 0:  31%|███       | 94/307 [00:00<00:02, 100.26it/s]
# Validation DataLoader 0:  31%|███       | 95/307 [00:00<00:02, 100.27it/s]
# Validation DataLoader 0:  31%|███▏      | 96/307 [00:00<00:02, 100.29it/s]
# Validation DataLoader 0:  32%|███▏      | 97/307 [00:00<00:02, 100.24it/s]
# Validation DataLoader 0:  32%|███▏      | 98/307 [00:00<00:02, 100.20it/s]
# Validation DataLoader 0:  32%|███▏      | 99/307 [00:00<00:02, 100.17it/s]
# Validation DataLoader 0:  33%|███▎      | 100/307 [00:00<00:02, 100.17it/s]
# Validation DataLoader 0:  79%|███████▉  | 242/307 [00:02<00:00, 99.90it/s]
# Validation DataLoader 0:  79%|███████▉  | 243/307 [00:02<00:00, 99.90it/s]
# Validation DataLoader 0:  79%|███████▉  | 244/307 [00:02<00:00, 99.91it/s]
# Validation DataLoader 0:  80%|███████▉  | 245/307 [00:02<00:00, 99.89it/s]
# Validation DataLoader 0:  80%|████████  | 246/307 [00:02<00:00, 99.88it/s]
# Validation DataLoader 0:  80%|████████  | 247/307 [00:02<00:00, 99.87it/s]
# Validation DataLoader 0:  81%|████████  | 248/307 [00:02<00:00, 99.87it/s]
# Validation DataLoader 0:  81%|████████  | 249/307 [00:02<00:00, 99.85it/s]
# Validation DataLoader 0:  81%|████████▏ | 250/307 [00:02<00:00, 99.81it/s]
# Validation DataLoader 0:  82%|████████▏ | 251/307 [00:02<00:00, 99.81it/s]
# Validation DataLoader 0:  82%|████████▏ | 252/307 [00:02<00:00, 99.79it/s]
# Validation DataLoader 0:  82%|████████▏ | 253/307 [00:02<00:00, 99.77it/s]
# Validation DataLoader 0:  83%|████████▎ | 254/307 [00:02<00:00, 99.76it/s]
# Validation DataLoader 0:  83%|████████▎ | 255/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  83%|████████▎ | 256/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  84%|████████▎ | 257/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  84%|████████▍ | 258/307 [00:02<00:00, 99.77it/s]
# Validation DataLoader 0:  84%|████████▍ | 259/307 [00:02<00:00, 99.79it/s]
# Validation DataLoader 0:  85%|████████▍ | 260/307 [00:02<00:00, 99.79it/s]
# Validation DataLoader 0:  85%|████████▌ | 261/307 [00:02<00:00, 99.80it/s]
# Validation DataLoader 0:  85%|████████▌ | 262/307 [00:02<00:00, 99.80it/s]
# Validation DataLoader 0:  86%|████████▌ | 263/307 [00:02<00:00, 99.80it/s]
# Validation DataLoader 0:  86%|████████▌ | 264/307 [00:02<00:00, 99.79it/s]
# Validation DataLoader 0:  86%|████████▋ | 265/307 [00:02<00:00, 99.80it/s]
# Validation DataLoader 0:  87%|████████▋ | 266/307 [00:02<00:00, 99.78it/s]
# Validation DataLoader 0:  87%|████████▋ | 267/307 [00:02<00:00, 99.77it/s]
# Validation DataLoader 0:  87%|████████▋ | 268/307 [00:02<00:00, 99.76it/s]
# Validation DataLoader 0:  88%|████████▊ | 269/307 [00:02<00:00, 99.78it/s]
# Validation DataLoader 0:  88%|████████▊ | 270/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  88%|████████▊ | 271/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  89%|████████▊ | 272/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  89%|████████▉ | 273/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  89%|████████▉ | 274/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  90%|████████▉ | 275/307 [00:02<00:00, 99.72it/s]
# Validation DataLoader 0:  90%|████████▉ | 276/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  90%|█████████ | 277/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  91%|█████████ | 278/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  91%|█████████ | 279/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  91%|█████████ | 280/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  92%|█████████▏| 281/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  92%|█████████▏| 282/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  92%|█████████▏| 283/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  93%|█████████▎| 284/307 [00:02<00:00, 99.72it/s]
# Validation DataLoader 0:  93%|█████████▎| 285/307 [00:02<00:00, 99.72it/s]
# Validation DataLoader 0:  93%|█████████▎| 286/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  93%|█████████▎| 287/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  94%|█████████▍| 288/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  94%|█████████▍| 289/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  94%|█████████▍| 290/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  95%|█████████▍| 291/307 [00:02<00:00, 99.73it/s]
# Validation DataLoader 0:  95%|█████████▌| 292/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  95%|█████████▌| 293/307 [00:02<00:00, 99.74it/s]
# Validation DataLoader 0:  96%|█████████▌| 294/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  96%|█████████▌| 295/307 [00:02<00:00, 99.76it/s]
# Validation DataLoader 0:  96%|█████████▋| 296/307 [00:02<00:00, 99.77it/s]
# Validation DataLoader 0:  97%|█████████▋| 297/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  97%|█████████▋| 298/307 [00:02<00:00, 99.76it/s]
# Validation DataLoader 0:  97%|█████████▋| 299/307 [00:02<00:00, 99.75it/s]
# Validation DataLoader 0:  98%|█████████▊| 300/307 [00:03<00:00, 99.73it/s]
# Validation DataLoader 0:  98%|█████████▊| 301/307 [00:03<00:00, 99.71it/s]
# Validation DataLoader 0:  98%|█████████▊| 302/307 [00:03<00:00, 99.72it/s]
# Validation DataLoader 0:  99%|█████████▊| 303/307 [00:03<00:00, 99.70it/s]
# Validation DataLoader 0:  99%|█████████▉| 304/307 [00:03<00:00, 99.69it/s]
# Validation DataLoader 0:  99%|█████████▉| 305/307 [00:03<00:00, 99.70it/s]
# Validation DataLoader 0: 100%|█████████▉| 306/307 [00:03<00:00, 99.69it/s]
# Validation DataLoader 0: 100%|██████████| 307/307 [00:03<00:00, 99.84it/s]
# Epoch 2: 100%|██████████| 1225/1225 [00:19<00:00, 63.65it/s, v_num=3, loss/train=0.345, MAE/val=0.337, MAE/train=0.357]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/307 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/307 [00:00<00:01, 157.13it/s]
# Validation DataLoader 0:   1%|          | 2/307 [00:00<00:02, 121.88it/s]
# Validation DataLoader 0:   1%|          | 3/307 [00:00<00:02, 112.63it/s]
# Validation DataLoader 0:   1%|▏         | 4/307 [00:00<00:02, 107.73it/s]
# Validation DataLoader 0:   2%|▏         | 5/307 [00:00<00:02, 105.04it/s]
# ...
# Validation DataLoader 0:  32%|███▏      | 97/307 [00:00<00:02, 98.00it/s]
# Validation DataLoader 0:  32%|███▏      | 98/307 [00:01<00:02, 97.98it/s]
# Validation DataLoader 0:  32%|███▏      | 99/307 [00:01<00:02, 98.01it/s]
# Validation DataLoader 0:  33%|███▎      | 100/307 [00:01<00:02, 97.99it/s]
# Validation DataLoader 0:  33%|███▎      | 101/307 [00:01<00:02, 97.97it/s]
307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  80%|████████  | 247/307 [00:02<00:00, 97.71it/s]
# Validation DataLoader 0:  81%|████████  | 248/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  81%|████████  | 249/307 [00:02<00:00, 97.71it/s]
# Validation DataLoader 0:  81%|████████▏ | 250/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  82%|████████▏ | 251/307 [00:02<00:00, 97.73it/s]
# Validation DataLoader 0:  82%|████████▏ | 252/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 253/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  83%|████████▎ | 254/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  83%|████████▎ | 255/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  83%|████████▎ | 256/307 [00:02<00:00, 97.75it/s]
# Validation DataLoader 0:  84%|████████▎ | 257/307 [00:02<00:00, 97.75it/s]
# Validation DataLoader 0:  84%|████████▍ | 258/307 [00:02<00:00, 97.75it/s]
# Validation DataLoader 0:  84%|████████▍ | 259/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  85%|████████▍ | 260/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  85%|████████▌ | 261/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  85%|████████▌ | 262/307 [00:02<00:00, 97.74it/s]
# Validation DataLoader 0:  86%|████████▌ | 263/307 [00:02<00:00, 97.75it/s]
# Validation DataLoader 0:  86%|████████▌ | 264/307 [00:02<00:00, 97.75it/s]
# Validation DataLoader 0:  86%|████████▋ | 265/307 [00:02<00:00, 97.73it/s]
# Validation DataLoader 0:  87%|████████▋ | 266/307 [00:02<00:00, 97.73it/s]
# Validation DataLoader 0:  87%|████████▋ | 267/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  87%|████████▋ | 268/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  88%|████████▊ | 269/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  88%|████████▊ | 270/307 [00:02<00:00, 97.72it/s]
# Validation DataLoader 0:  88%|████████▊ | 271/307 [00:02<00:00, 97.70it/s]
# Validation DataLoader 0:  89%|████████▊ | 272/307 [00:02<00:00, 97.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 273/307 [00:02<00:00, 97.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 274/307 [00:02<00:00, 97.70it/s]
# Validation DataLoader 0:  90%|████████▉ | 275/307 [00:02<00:00, 97.71it/s]
# Validation DataLoader 0:  90%|████████▉ | 276/307 [00:02<00:00, 97.69it/s]
# Validation DataLoader 0:  90%|█████████ | 277/307 [00:02<00:00, 97.68it/s]
# Validation DataLoader 0:  91%|█████████ | 278/307 [00:02<00:00, 97.67it/s]
# Validation DataLoader 0:  91%|█████████ | 279/307 [00:02<00:00, 97.68it/s]
# Validation DataLoader 0:  91%|█████████ | 280/307 [00:02<00:00, 97.67it/s]
# Validation DataLoader 0:  92%|█████████▏| 281/307 [00:02<00:00, 97.67it/s]
# Validation DataLoader 0:  92%|█████████▏| 282/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  92%|█████████▏| 283/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  93%|█████████▎| 284/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  93%|█████████▎| 285/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  93%|█████████▎| 286/307 [00:02<00:00, 97.62it/s]
# Validation DataLoader 0:  93%|█████████▎| 287/307 [00:02<00:00, 97.63it/s]
# Validation DataLoader 0:  94%|█████████▍| 288/307 [00:02<00:00, 97.63it/s]
# Validation DataLoader 0:  94%|█████████▍| 289/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  94%|█████████▍| 290/307 [00:02<00:00, 97.63it/s]
# Validation DataLoader 0:  95%|█████████▍| 291/307 [00:02<00:00, 97.64it/s]
# Validation DataLoader 0:  95%|█████████▌| 292/307 [00:02<00:00, 97.66it/s]
# Validation DataLoader 0:  95%|█████████▌| 293/307 [00:03<00:00, 97.66it/s]
# Validation DataLoader 0:  96%|█████████▌| 294/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  96%|█████████▌| 295/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  96%|█████████▋| 296/307 [00:03<00:00, 97.66it/s]
# Validation DataLoader 0:  97%|█████████▋| 297/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  97%|█████████▋| 298/307 [00:03<00:00, 97.68it/s]
# Validation DataLoader 0:  97%|█████████▋| 299/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  98%|█████████▊| 300/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  98%|█████████▊| 301/307 [00:03<00:00, 97.66it/s]
# Validation DataLoader 0:  98%|█████████▊| 302/307 [00:03<00:00, 97.67it/s]
# Validation DataLoader 0:  99%|█████████▊| 303/307 [00:03<00:00, 97.68it/s]
# Validation DataLoader 0:  99%|█████████▉| 304/307 [00:03<00:00, 97.68it/s]
# Validation DataLoader 0:  99%|█████████▉| 305/307 [00:03<00:00, 97.68it/s]
# Validation DataLoader 0: 100%|█████████▉| 306/307 [00:03<00:00, 97.70it/s]
# Validation DataLoader 0: 100%|██████████| 307/307 [00:03<00:00, 97.86it/s]
# Epoch 36:   1%|          | 15/1225 [00:00<00:21, 55.18it/s, v_num=3, loss/train=0.275, MAE/val=0.283, MAE/train=0.294]

# %%
pl_model_basic_flow = LModel_NF(basic_flow)
trainer = create_trainer("basic_flow", max_epochs = 30)
trainer.fit(
    model=pl_model_basic_flow,
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)

# %%
pl_model_nu_flow = LModel_NF(nu_flow)
trainer = create_trainer("nu_flow", max_epochs = 30)
trainer.fit(
    model=pl_model_nu_flow,
    train_dataloaders=train_loader,
    val_dataloaders=val_loader
)

# %%
checkpoint = torch.load('../checkpoints/parton/mlp-v1.ckpt')
state_dict = checkpoint["state_dict"]
model_dict = {key.removeprefix("model."):val for key, val in state_dict.items()}
mlp_model.load_state_dict(model_dict)

checkpoint = torch.load('../checkpoints/parton/basic_flow-v1.ckpt')
state_dict = checkpoint["state_dict"]
model_dict = {key.removeprefix("model."):val for key, val in state_dict.items()}
basic_flow.load_state_dict(model_dict)

checkpoint = torch.load('../checkpoints/parton/nu_flow-v1.ckpt')
state_dict = checkpoint["state_dict"]
model_dict = {key.removeprefix("model."):val for key, val in state_dict.items()}
nu_flow.load_state_dict(model_dict)
# Out:
# <All keys matched successfully>

# %%
X_test_DM = pd.DataFrame(scaler_X.transform(np.array(test_raw_DM[X_vars])), columns=X_vars)[:20]
y_test_DM = pd.DataFrame(scaler_y.transform(np.array(test_raw_DM[y_vars])), columns=y_vars)[:20]

with torch.no_grad():
    pred_basic = basic_flow.sample(num_samples = 10000, context=torch.tensor(X_test_DM.values, dtype = torch.float32))
    pred_nuflows = nu_flow.sample(num_samples = 10000, context=torch.tensor(X_test_DM.values, dtype = torch.float32))
    pred_mlp = mlp_model.forward(torch.tensor(X_test_DM.values, dtype = torch.float32))
    
pred_mlp = scaler_y.inverse_transform(pred_mlp)
y_test_unscaled = scaler_y.inverse_transform(y_test_DM)

# %%
from pathlib import Path
Path("../plots/parton").mkdir(parents=True, exist_ok=True)

# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "monospace",
#     "font.monospace": "Computer Modern Typewriter"
# })
plt.rcParams.update(plt.rcParamsDefault)
fig, axes = plt.subplots(2,3, figsize=(20,10))
for i, ax in enumerate(axes.flat):
    ax.axvline(y_test_unscaled[i][5], c='red', label = "True value", linestyle = '--', linewidth = 2)
    ax.axvline(pred_mlp[i][5], c='green', label = "MLP prediction", linewidth = 2)
    ax.hist(scaler_y.inverse_transform(pred_basic[i])[:,5], bins = 100, range = (-1000, 1000), alpha=.5, label = "Basic Flows sampling")
    ax.hist(scaler_y.inverse_transform(pred_nuflows[i])[:,5], bins = 100, range = (-1000, 1000), alpha=.5, label = "Nu-Flows-like sampling")
    ax.legend(loc='upper right', fontsize=10)
    ax.set_xlabel("P_phi_z, GeV")
fig.suptitle("Mediator Pz estimation for separate events", fontsize = 20)
plt.savefig("../plots/parton/Pz_NF_comparison.pdf")
plt.show()

# %%
X_test_DM = pd.DataFrame(scaler_X.transform(np.array(test_raw_DM[X_vars])), columns=X_vars)
y_test_DM = pd.DataFrame(scaler_y.transform(np.array(test_raw_DM[y_vars])), columns=y_vars)
y_test_unscaled = scaler_y.inverse_transform(y_test_DM)

# %%
from torchmetrics.regression import MeanAbsoluteError
from torcheval.metrics.functional import mean_squared_error
with torch.no_grad():
    pred_mlp = mlp_model.forward(torch.tensor(X_test_DM.values, dtype = torch.float32))
mean_absolute_error = MeanAbsoluteError()
print(f'MAE: {mean_absolute_error(torch.tensor(pred_mlp), torch.tensor(y_test_DM.values)):.4f}')
print(f'MSE: {mean_squared_error(torch.tensor(pred_mlp), torch.tensor(y_test_DM.values)):.4f}')
# Out:
# MAE: 0.5277
# MSE: 0.7118

# %%
def plot_targets(y_vars, pred, y_test_unscaled, bins = 100, alpha = 0.5, 
                bin_ranges = [(-1000, 1000), (-1000, 1000), (-1000, 1000), (-1000, 1000), (-1000, 1000), (-1000, 1000)],
                name = 'MLP'):
    for i in range(len(y_vars)):
        plt.hist(pred[:, i], bins=bins, alpha=alpha, range=bin_ranges[i], label='reconstructed')
        plt.hist(y_test_unscaled[:, i], bins=bins, alpha=alpha, range=bin_ranges[i], label='true')
        plt.title(f'{y_vars[i]}, {name} reconstruction')
        plt.xlabel(y_vars[i])
        plt.legend()
        plt.savefig(f"../plots/parton/{y_vars[i]}_{name}.pdf")
        plt.show()

# %%
pred_mlp = scaler_y.inverse_transform(pred_mlp)
plot_targets(y_vars, pred_mlp, y_test_unscaled, name = 'MLP')

# %%
with torch.no_grad():
    pred_flows, _= torch.median(basic_flow.sample(num_samples = 10, context=torch.tensor(X_test_DM.values, dtype = torch.float32)), 1)
mean_absolute_error = MeanAbsoluteError()
print(f'MAE: {mean_absolute_error(torch.tensor(pred_flows), torch.tensor(y_test_DM.values))}')
print(f'MSE: {mean_squared_error(torch.tensor(pred_flows), torch.tensor(y_test_DM.values))}')
# Out:
# MAE: 328033665024.0
# MSE: 7.4638974517981115e+28

# %%
pred_flows = scaler_y.inverse_transform(pred_flows)
plot_targets(y_vars, pred_flows, y_test_unscaled, name = 'Basic_flows')

# %%
with torch.no_grad():
    pred_nuflows, _= torch.median(nu_flow.sample(num_samples = 5, context=torch.tensor(X_test_DM.values, dtype = torch.float32)), 1)
mean_absolute_error = MeanAbsoluteError()
print(f'MAE: {mean_absolute_error(torch.tensor(pred_nuflows), torch.tensor(y_test_DM.values))}')
print(f'MSE: {mean_squared_error(torch.tensor(pred_nuflows), torch.tensor(y_test_DM.values))}')
# Out:
# MAE: 0.6206443905830383
# MSE: 0.9023188457723635

# %%
pred_nuflows = scaler_y.inverse_transform(pred_nuflows)
plot_targets(y_vars, pred_nuflows, y_test_unscaled, name = 'Nu_flows')

# %%
import sc_misc
Cos_lep_light_true, Cos_lep_light_nophi_true = sc_misc.calculate_cosine_theory(test_raw_DM[X_vars], test_raw_DM[y_vars])

# %%
from scipy.stats import chisquare
def plot_cosine(pred, test_data, name, bins = 100, alpha = 0.5):
    Cos_lep_light_mixed_DM, Cos_lep_light_mixed_DM_nophi = sc_misc.calculate_cosine(pred, test_data[X_vars])
    pred_hist = np.histogram(Cos_lep_light_mixed_DM, bins = 50)[0]
    true_hist = np.histogram(Cos_lep_light_true, bins = 50)[0]
    print(f'Chi-squared statistics: {chisquare(pred_hist, true_hist)[0]:.1f}')
    print(f'Histogram MAE: {mean_absolute_error(torch.tensor(pred_hist), torch.tensor(true_hist)):.1f}')
    plt.hist(Cos_lep_light_mixed_DM, bins=bins, alpha=alpha, label='reconstructed')
    plt.hist(Cos_lep_light_mixed_DM_nophi, bins=bins, alpha=alpha, label='reconstructed_nophi')
    plt.hist(Cos_lep_light_true, bins=bins, alpha=1, label='true', histtype='step', linewidth = 2)
    plt.hist(Cos_lep_light_nophi_true, bins=bins, alpha=1, label='true_nophi', histtype='step', linewidth = 2)
    plt.title(r'$cos(\mu, d)_{TRF}$ reconstruction, DM, ' + name)
    plt.legend()
    plt.savefig(f"../plots/parton/Cos_DM_{name}.png")
    plt.show()

# %%
plot_cosine(pred_mlp, test_raw_DM, 'MLP')
# Out:
# Chi-squared statistics: 9150.0
# Histogram MAE: 729.2

# %%
plot_cosine(pred_flows, test_raw_DM, 'Basic_flows')
# Out:
# Chi-squared statistics: 2197.0
# Histogram MAE: 349.2

# %%
plot_cosine(pred_nuflows, test_raw_DM, 'Nu_flows')
# Out:
# Chi-squared statistics: 827.8
# Histogram MAE: 219.1
